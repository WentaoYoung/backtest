# %%
import pandas as pd

# %%
from data.parquet_io import resolve_factors_all_paths, read_factors_all_table

paths = resolve_factors_all_paths("data/parquet_loaded")
table = read_factors_all_table(paths)
df = table.to_pandas()

# %%
df
# Out:
#         s_info_windcode    trade_dt      LNCAP    MIDCAP     size_2  MIDCAP_2  \
# 0             000001.SZ  2018-08-01  16.569857 -2.919719  16.569857 -2.919719
# 1             000001.SZ  2018-08-02  16.546639 -2.922265  16.546639 -2.922265
# 2             000001.SZ  2018-08-03  16.543278 -2.930150  16.543278 -2.930150
# 3             000001.SZ  2018-08-06  16.546639 -2.908186  16.546639 -2.908186
# 4             000001.SZ  2018-08-07  16.572041 -2.907818  16.572041 -2.907818
# ...                 ...         ...        ...       ...        ...       ...
# 8102630       920819.BJ  2025-09-02  13.231878 -0.282378  13.231878 -0.282378
# 8102631       920819.BJ  2025-09-03  13.185358 -0.284880  13.185358 -0.284880
# 8102632       920819.BJ  2025-09-04  13.189883 -0.296057  13.189883 -0.296057
# 8102633       920819.BJ  2025-09-05  13.216611 -0.282553  13.216611 -0.282553
# 8102634       920819.BJ  2025-09-08  13.229712 -0.322131  13.229712 -0.322131
#
#            size_1
# ...
